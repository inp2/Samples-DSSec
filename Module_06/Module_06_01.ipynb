# %% [markdown]
# # Anomaly Detection with Unsupservised Learning

# %% [markdown]
# Anomaly detection is the identification of rare items, events or observations which raise suspicioins by differing significantly from the majority of the data. Anomalous data can be connected to some kind of problem or rare event. This connection makes it very interesting to be able to pick out which data points can be considered anomalies, as identifying these events are typically very interesting.
#
# Unsupervised anomaly detection technieques detect anomalies in an unlabeled test data set under the ssumption that the majority of the instances in the dataset are normal. It looks for instances that seem to fit least to the remainder of the dataset.

# %%
import numpy as np
import pandas as pd
from bat.log_to_dataframe import LogToDataFrame
# %matplotlib inline
import matplotlib.pyplot as plt
from bat import dataframe_to_matrix
import sklearn
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.cluster import KMeans, DBSCAN
from sklearn import preprocessing
import numpy as np

# %%
http_df = pd.read_csv('data/http_log.csv')

# %%
http_df.head()
# Out:
#                      ts                 uid       id.orig_h  id.orig_p  \
# 0  2012-Mar-16_07:30:00  CHEt7z3AzG4gyCNgci  192.168.202.79      50465
# 1  2012-Mar-16_07:30:00  CKnDAp2ohlvN6rpiXl  192.168.202.79      50467
# 2  2012-Mar-16_07:30:00  CNTrjn42F3LB58MZH6  192.168.202.79      50469
# 3  2012-Mar-16_07:30:00  C1D7mK1PlzKEnEyG03  192.168.202.79      50471
# 4  2012-Mar-16_07:30:00   CGF1bVMyl9ALKI32l  192.168.202.79      50473
#
#          id.resp_h  id.resp_p  trans_depth method             host  \
# 0  192.168.229.251         80            1   HEAD  192.168.229.251
# 1  192.168.229.251         80            1   HEAD  192.168.229.251
# 2  192.168.229.251         80            1   HEAD  192.168.229.251
# 3  192.168.229.251         80            1   HEAD  192.168.229.251
# 4  192.168.229.251         80            1   HEAD  192.168.229.251
#
#               uri  ... info_msg filename     tags  username password proxied  \
# 0  /DEASLog02.nsf  ...        -        -  (empty)         -        -       -
# 1  /DEASLog03.nsf  ...        -        -  (empty)         -        -       -
# 2  /DEASLog04.nsf  ...        -        -  (empty)         -        -       -
# 3  /DEASLog05.nsf  ...        -        -  (empty)         -        -       -
# 4    /DEASLog.nsf  ...        -        -  (empty)         -        -       -
#
#   orig_fuids orig_mime_types resp_fuids resp_mime_types
# 0          -               -          -               -
# 1          -               -          -               -
# 2          -               -          -               -
# 3          -               -          -               -
# 4          -               -          -               -
#
# [5 rows x 27 columns]

# %% [markdown]
# Remove columns with alot of null vaules

# %%
http_df.drop(columns=['filename', 'tags', 'username', 'password', 'proxied', 'orig_fuids', 'orig_mime_types', 'resp_fuids', 'resp_mime_types', 'info_code', 'info_msg', 'referrer'])
# Out:
#                        ts                 uid       id.orig_h  id.orig_p  \
# 0    2012-Mar-16_07:30:00  CHEt7z3AzG4gyCNgci  192.168.202.79      50465
# 1    2012-Mar-16_07:30:00  CKnDAp2ohlvN6rpiXl  192.168.202.79      50467
# 2    2012-Mar-16_07:30:00  CNTrjn42F3LB58MZH6  192.168.202.79      50469
# 3    2012-Mar-16_07:30:00  C1D7mK1PlzKEnEyG03  192.168.202.79      50471
# 4    2012-Mar-16_07:30:00   CGF1bVMyl9ALKI32l  192.168.202.79      50473
# 5    2012-Mar-16_07:30:00  CQ7uZu2HtGNngGZl5c  192.168.202.79      50475
# 18   192.168.229.251         80            1   HEAD  192.168.229.251
# 19   192.168.229.251         80            1   HEAD  192.168.229.251
# 20   192.168.229.251         80            1   HEAD  192.168.229.251
# 21   192.168.229.251         80            1   HEAD  192.168.229.251
# 22   192.168.229.251         80            1   HEAD  192.168.229.251
# 23   192.168.229.251         80            1   HEAD  192.168.229.251
# 24   192.168.229.251         80            1   HEAD  192.168.229.251
# 25   192.168.229.251         80            1   HEAD  192.168.229.251
# 26   192.168.229.251         80            1   HEAD  192.168.229.251
# 27   192.168.229.251         80            1   HEAD  192.168.229.251
# 28   192.168.229.251         80            1   HEAD  192.168.229.251
# 29   192.168.229.251         80            1   HEAD  192.168.229.251
# ..               ...        ...          ...    ...              ...
# 570  192.168.229.156         80            1    GET  192.168.229.156
# 571  192.168.229.101         80            1    GET  192.168.229.101
# 572  192.168.229.153       5357            1   HEAD  192.168.229.153
# 573  192.168.229.156         80            1    GET  192.168.229.156
# 574  192.168.229.101         80            1    GET  192.168.229.101
# 575  192.168.229.156         80            1    GET  192.168.229.156
# 576  192.168.229.153       5357            1   HEAD  192.168.229.153
# 577  192.168.229.101         80            1    GET  192.168.229.101
# 578  192.168.229.156         80            1    GET  192.168.229.156
# 579  192.168.229.251       5488            1    GET  192.168.229.251
# 580  192.168.229.153       5357            1   HEAD  192.168.229.153
# 581  192.168.229.101         80            1    GET  192.168.229.101
# 582  192.168.229.156         80            1    GET  192.168.229.156
# 583  192.168.229.251       5488            1    GET  192.168.229.251
# 584  192.168.229.153       5357            1   HEAD  192.168.229.153
# 585  192.168.229.101         80            1    GET  192.168.229.101
# 586  192.168.229.156         80            1    GET  192.168.229.156
# 587  192.168.229.156         80            1    GET  192.168.229.156
# 588  192.168.229.251       5488            1   HEAD  192.168.229.251
# 589  192.168.229.101         80            1    GET  192.168.229.101
# 590  192.168.229.153       5357            1   HEAD  192.168.229.153
# 591  192.168.229.251       5488            1   HEAD  192.168.229.251
# 592  192.168.229.101         80            1    GET  192.168.229.101
# 593  192.168.229.153       5357            1    GET  192.168.229.153
# 594  192.168.229.153       5357            1   HEAD  192.168.229.153
# 595  192.168.229.153       5357            1    GET  192.168.229.153
# 596  192.168.229.251       5488            1   HEAD  192.168.229.251
# 597  192.168.229.101         80            1    GET  192.168.229.101
# 598  192.168.229.153       5357            1   HEAD  192.168.229.153
# 599  192.168.229.153       5357            1    GET  192.168.229.153
#
#                                                    uri  \
# 0                                       /DEASLog02.nsf
# 1                                       /DEASLog03.nsf
# 2                                       /DEASLog04.nsf
# 3                                       /DEASLog05.nsf
# 4                                         /DEASLog.nsf
# 5                                         /decsadm.nsf
# 6                                         /decslog.nsf
# 7                                       /DEESAdmin.nsf
# 8                                       /dirassist.nsf
# 9                                        /doladmin.nsf
# 10                                       /domadmin.nsf
# 11                                         /domcfg.nsf
# 12                                       /domguide.nsf
# 13                                         /domlog.nsf
# 14                                          /dspug.nsf
# 15                                        /events4.nsf
# 16                                        /events5.nsf
# 17                                         /events.nsf
# 18                                          /event.nsf
# 19                                       /homepage.nsf
# 20                      /iNotes/Forms5.nsf/$DefaultNav
# 21                                         /jotter.nsf
# 22                                         /leiadm.nsf
# 23                                         /leilog.nsf
# 24                                         /leivlt.nsf
# 25                                          /log4a.nsf
# 26                                            /log.nsf
# 27                                       /l_domlog.nsf
# 28                                            /mab.nsf
# 29                                         /mail10.box
# ..                                                 ...
# 570                         /wp-content/plugins/eshop/
# 571                /wp-content/plugins/w3-total-cache/
# 572                              /admin_area/index.php
# 573                     /wp-content/plugins/contactme/
# 574                  /wp-content/plugins/wp-mail-smtp/
# 575           /wp-content/plugins/portfolio-slideshow/
# 576                                /bb-admin/index.php
# 577                    /wp-content/plugins/buddypress/
# 578         /wp-content/plugins/disqus-comment-system/
# 579  /cgi-bin/mj_wwwusr?passw=&list=GLOBAL&user=&fu...
# 580                                /bb-admin/login.php
# 581  /wp-content/plugins/like-button-plugin-for-wor...
# 582  /cgi-bin/mj_wwwusr?passw=&list=GLOBAL&user=&fu...
# 583                                                  /
# 584                                /bb-admin/admin.php
# 585              /wp-content/plugins/wp-security-scan/
# 586                                   /ts/in.cgi?open2
# 587                                        /robots.txt
# 588                                             /blog/
# 589             /wp-content/plugins/network-publisher/
# 590                                    /admin/home.php
# 591                                           /weblog/
# 592  /wp-content/plugins/really-simple-facebook-twi...
# 593                          /nmaplowercheck1331872977
# 594                             /admin_area/login.html
# 595                    /wp-content/plugins/gtranslate/
# 596                                          /weblogs/
# 597                   /wp-content/plugins/simple-tags/
# 598                             /admin_area/index.html
# 599           /wp-content/plugins/all-in-one-seo-pack/
#
#                                             user_agent  request_body_len  \
# 0    Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 1    Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 2    Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 3    Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 4    Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 5    Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 6    Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 7    Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 8    Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 9    Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 10   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 11   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 12   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 13   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 14   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 15   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 16   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 17   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 18   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 19   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 20   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 21   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 22   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 23   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 24   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 25   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 26   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 27   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 28   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 29   Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# ..                                                 ...               ...
# 570  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 571  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 572  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 573  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 574  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 575  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 576  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 577  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 578  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 579  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 580  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 581  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 582  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 583  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 584  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 585  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 586  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 587  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 588  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 589  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 590  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 591  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 592  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 593  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 594  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 595  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 596  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 597  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 598  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
# 599  Mozilla/5.0 (compatible; Nmap Scripting Engine...                 0
#
#      response_body_len status_code           status_msg
# 0                    0         404            Not Found
# 1                    0         404            Not Found
# 2                    0         404            Not Found
# 3                    0         404            Not Found
# 4                    0         404            Not Found
# 5                    0         404            Not Found
# 6                    0         404            Not Found
# 7                    0         404            Not Found
# 8                    0         404            Not Found
# 9                    0         404            Not Found
# 10                   0         404            Not Found
# 11                   0         404            Not Found
# 12                   0         404            Not Found
# 13                   0         404            Not Found
# 14                   0         404            Not Found
# 15                   0         404            Not Found
# 16                   0         404            Not Found
# 17                   0         404            Not Found
# 18                   0         404            Not Found
# 19                   0         404            Not Found
# 20                   0         404            Not Found
# 21                   0         404            Not Found
# 22                   0         404            Not Found
# 23                   0         404            Not Found
# 24                   0         404            Not Found
# 25                   0         404            Not Found
# 26                   0         404            Not Found
# 27                   0         404            Not Found
# 28                   0         404            Not Found
# 29                   0         404            Not Found
# ..                 ...         ...                  ...
# 570                303         404            Not Found
# 571                238         404            NOT FOUND
# 572                  0         503  Service Unavailable
# 573                307         404            Not Found
# 574                238         404            NOT FOUND
# 575                317         404            Not Found
# 576                  0         503  Service Unavailable
# 577                238         404            NOT FOUND
# 578                319         404            Not Found
# 579               1635         404            Not Found
# 580                  0         503  Service Unavailable
# 581                238         404            NOT FOUND
# 582                295         404            Not Found
# 583                579         401        Access denied
# 584                  0         503  Service Unavailable
# 585                238         404            NOT FOUND
# 586                287         404            Not Found
# 587                361         200                   OK
# 588                  0         404            Not Found
# 589                238         404            NOT FOUND
# 590                  0         503  Service Unavailable
# 591                  0         404            Not Found
# 592                238         404            NOT FOUND
# 593                326         503  Service Unavailable
# 594                  0         503  Service Unavailable
# 595                326         503  Service Unavailable
# 596                  0         404            Not Found
# 597                238         404            NOT FOUND
# 598                  0         503  Service Unavailable
# 599                326         503  Service Unavailable
#
# [600 rows x 15 columns]

# %% [markdown]
# Lets look at our data

# %%
http_df[['request_body_len', 'response_body_len']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5dc8c33c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5dc8c0c710>]],
#       dtype=object)

# %% [markdown]
# # Exercise 1
#
# Build a time-series analysis of this data

# %%
http_df['ts'] = pd.to_datetime(http_df['ts'], format='%Y-%b-%d_%H:%M:%S')
http_df = http_df.set_index('ts')
http_df['request_body_len'].resample('1S').sum().plot()

# %%
http_df['response_body_len'].resample('1S').sum().plot()

# %% [markdown]
# We have a mix of quantitative and qualitative data. We need a way to handle both data types in a generalized way. We will rely on the label encoder to convert the qualitative into machine-readable form.

# %%
http_df.drop(columns=['uid'])
# Out:
#                           id.orig_h  id.orig_p        id.resp_h  id.resp_p  \
# ts
# 2012-03-16 07:30:00  192.168.202.79      50465  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50467  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50469  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50471  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50473  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50475  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50477  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50479  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50481  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50483  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50485  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50487  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50489  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50491  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50493  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50495  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50497  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50499  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50501  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50503  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50504  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50506  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50508  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50510  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50512  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50514  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50516  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50518  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50520  192.168.229.251         80
# 2012-03-16 07:30:00  192.168.202.79      50522  192.168.229.251         80
# ...                             ...        ...              ...        ...
# 2012-03-16 07:47:10  192.168.202.79      40688  192.168.229.156         80
# 2012-03-16 07:47:10  192.168.202.79      50252  192.168.229.101         80
# 2012-03-16 07:47:10  192.168.202.79      39275  192.168.229.153       5357
# 2012-03-16 07:47:10  192.168.202.79      40696  192.168.229.156         80
# 2012-03-16 07:47:10  192.168.202.79      50258  192.168.229.101         80
# 2012-03-16 07:47:10  192.168.202.79      40700  192.168.229.156         80
# 2012-03-16 07:47:10  192.168.202.79      39281  192.168.229.153       5357
# 2012-03-16 07:47:10  192.168.202.79      50263  192.168.229.101         80
# 2012-03-16 07:47:10  192.168.202.79      40705  192.168.229.156         80
# 2012-03-16 07:47:10  192.168.202.79      34150  192.168.229.251       5488
# 2012-03-16 07:47:10  192.168.202.79      39290  192.168.229.153       5357
# 2012-03-16 07:47:10  192.168.202.79      50269  192.168.229.101         80
# 2012-03-16 07:47:11  192.168.202.79      40714  192.168.229.156         80
# 2012-03-16 07:47:11  192.168.202.79      34156  192.168.229.251       5488
# 2012-03-16 07:47:11  192.168.202.79      39298  192.168.229.153       5357
# 2012-03-16 07:47:11  192.168.202.79
Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:10  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:10  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:10  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:10  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:10  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:10  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:10  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:10  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:10  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:10  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:10  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
# 2012-03-16 07:47:11  Mozilla/5.0 (compatible; Nmap Scripting Engine...  ...
#
#                      info_msg  filename     tags username password proxied  \
# ts
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# 2012-03-16 07:30:00         -         -  (empty)        -        -       -
# ...                       ...       ...      ...      ...      ...     ...
# 2012-03-16 07:47:10         -         -  (empty)        -        -       -
# 2012-03-16 07:47:10         -         -  (empty)        -        -       -
# 2012-03-16 07:47:10         -         -  (empty)        -        -       -
# 2012-03-16 07:47:10         -         -  (empty)        -        -       -
# 2012-03-16 07:47:10         -         -  (empty)        -        -       -
# 2012-03-16 07:47:10         -         -  (empty)        -        -       -
# 2012-03-16 07:47:10         -         -  (empty)        -        -       -
# 2012-03-16 07:47:10         -         -  (empty)        -        -       -
# 2012-03-16 07:47:10         -         -  (empty)        -        -       -
# 2012-03-16 07:47:10         -         -  (empty)        -        -       -
# 2012-03-16 07:47:10         -         -  (empty)        -        -       -
# 2012-03-16 07:47:10         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
# 2012-03-16 07:47:11         -         -  (empty)        -        -       -
#
#                     orig_fuids orig_mime_types          resp_fuids  \
# ts
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# 2012-03-16 07:30:00          -               -                   -
# ...                        ...             ...                 ...
# 2012-03-16 07:47:10          -               -  FvP9WW26lOst5CV5J9
# 2012-03-16 07:47:10          -               -  FDS1Z61eTHrd6mSbYd
# 2012-03-16 07:47:10          -               -                   -
# 2012-03-16 07:47:10          -               -  FRP32Q3dZwgKXwf2ta
# 2012-03-16 07:47:10          -               -   FT8RYN3izNXs7Hu71
# 2012-03-16 07:47:10          -               -  Fp55to1Xs0zq4Dlqjc
# 2012-03-16 07:47:10          -               -                   -
# 2012-03-16 07:47:10          -               -   FHmeuV8kcfay5aj0f
# 2012-03-16 07:47:10          -               -  FSJTxe1QAsEHxJlqy4
# 2012-03-16 07:47:10          -               -    FiFpjuHFvJ7VFTBe
# 2012-03-16 07:47:10          -               -                   -
# 2012-03-16 07:47:10          -               -  FGOLwJ3QMB3272PrB6
# 2012-03-16 07:47:11          -               -  FZvRPB1ty4rJTZDyy8
# 2012-03-16 07:47:11          -               -  FEkC313CrIGln2Nebd
# 2012-03-16 07:47:11          -               -                   -
# 2012-03-16 07:47:11          -               -  FfeQEa2mm9Awz7E2Vj
# 2012-03-16 07:47:11          -               -  FxR7b33dKjHrouAyX2
# 2012-03-16 07:47:11          -               -  FZn0La4vk5sCR7czC9
# 2012-03-16 07:47:11          -               -                   -
# 2012-03-16 07:47:11          -               -    FeXfokGF3B0OhSYo
# 2012-03-16 07:47:11          -               -                   -
# 2012-03-16 07:47:11          -               -                   -
# 2012-03-16 07:47:11          -               -  FlGmno3mr27poWK2t4
# 2012-03-16 07:47:11          -               -  FBIKVo49ie8uJnXawj
# 2012-03-16 07:47:11          -               -                   -
# 2012-03-16 07:47:11          -               -   FS3Itc2I2Q2KJNgrj
# 2012-03-16 07:47:11          -               -                   -
# 2012-03-16 07:47:11          -               -  FCshk224n44luILLzd
# 2012-03-16 07:47:11          -               -                   -
# 2012-03-16 07:47:11          -               -   FuFfOpLYktPyz9izk
#
#                     resp_mime_types
# ts
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# 2012-03-16 07:30:00               -
# ...                             ...
# 2012-03-16 07:47:10       text/html
# 2012-03-16 07:47:10       text/html
# 2012-03-16 07:47:10               -
# 2012-03-16 07:47:10       text/html
# 2012-03-16 07:47:10       text/html
# 2012-03-16 07:47:10       text/html
# 2012-03-16 07:47:10               -
# 2012-03-16 07:47:10       text/html
# 2012-03-16 07:47:10       text/html
# 2012-03-16 07:47:10       text/html
# 2012-03-16 07:47:10               -
# 2012-03-16 07:47:10       text/html
# 2012-03-16 07:47:11       text/html
# 2012-03-16 07:47:11       text/html
# 2012-03-16 07:47:11               -
# 2012-03-16 07:47:11       text/html
# 2012-03-16 07:47:11       text/html
# 2012-03-16 07:47:11      text/plain
# 2012-03-16 07:47:11               -
# 2012-03-16 07:47:11       text/html
# 2012-03-16 07:47:11               -
# 2012-03-16 07:47:11               -
# 2012-03-16 07:47:11       text/html
# 2012-03-16 07:47:11       text/html
# 2012-03-16 07:47:11               -
# 2012-03-16 07:47:11       text/html
# 2012-03-16 07:47:11               -
# 2012-03-16 07:47:11       text/html
# 2012-03-16 07:47:11               -
# 2012-03-16 07:47:11       text/html
#
# [600 rows x 25 columns]

# %%
# Use the bat DataframeToMatrix class (handles categorical data)
# You can see below it uses a heuristic to detect category data. When doing
# this for real we should explicitly convert before sending to the transformer.
to_matrix = dataframe_to_matrix.DataFrameToMatrix()
bro_matrix = to_matrix.fit_transform(http_df)
# Out:
# Changing column id.orig_h to category...
# Changing column id.resp_h to category...
# Changing column method to category...
# Changing column host to category...
# Changing column referrer to category...
# Changing column user_agent to category...
# Changing column status_code to category...
# Changing column status_msg to category...
# Changing column info_code to category...
# Changing column info_msg to category...
# Changing column filename to category...
# Changing column tags to category...
# Changing column username to category...
# Changing column password to category...
# Changing column proxied to category...
# Changing column orig_fuids to category...
# Changing column orig_mime_types to category...
# Changing column resp_mime_types to category...
# Normalizing column id.orig_p...
# Normalizing column id.resp_p...
# Normalizing column trans_depth...
# Normalizing column request_body_len...
# Normalizing column response_body_len...

# %% [markdown]
# K-Means clustering is a method that aims to partition n observations into k clusters in which each observations belongs to the cluster with the nearest mean, serving as a prototype of the cluster.
#
# K-means clustering is unsupervised learning. The goal of this algorithm is to find groups in the daa, with the number of groups represented by the variable K. The algorithm works iteratively to assign each data point to one of K groups based on the features that are provided. Data points are clustered based on feature similarity. The results of the K-means clustering algorithm are:
#
# 1. The centroids of the K clusters, which can be used to label new data
# 2. Labels for the training data (each data point is assigned to a sinle cluster)
#
# Rather than defining groups before you look at the data, clustering allows you to find and analzye the groups that have formed organically.

# %%
kmeans = KMeans(n_clusters=6).fit_predict(bro_matrix)
projection = TSNE().fit_transform(bro_matrix)

http_df['x'] = projection[:, 0]
http_df['y'] = projection[:, 1]
http_df['cluster'] = kmeans
http_df[['x', 'y', 'cluster']].head()
# Out:
#                             x          y  cluster
# ts
# 2012-03-16 07:30:00  1.127772 -33.035049        1
# 2012-03-16 07:30:00  1.026558 -33.075424        1
# 2012-03-16 07:30:00  0.914358 -33.119667        1
# 2012-03-16 07:30:00  1.068465 -32.687183        1
# 2012-03-16 07:30:00  0.993970 -32.620308        1

# %%
plt.rcParams['font.size'] = 18.0
plt.rcParams['figure.figsize'] = 15.0, 7.0

# Group by cluster
cluster_groups = http_df.groupby('cluster')

# plot the ml results
fig, ax = plt.subplots()
colors = {0: 'red', 1:'orange', 2:'yellow', 3:'green', 4:'blue', 
          5:'purple', 6:'brown', 7:'black'}
for key, group in cluster_groups:
    group.plot(ax=ax, kind='scatter', x='x', y='y', alpha=0.5, s=250,
              label='Cluster: {:d}'.format(key), color=colors[key])

# %% [markdown]
# # Exercise 2
#
# Play around with the number of clusters and see what number you best
# represents the data

# %%
# Now print out the details for each cluster
pd.set_option('display.width', 1000)
show_fields = ['trans_depth']
for key, group in cluster_groups:
    print('\nCluster {:d}: {:d} observations'.format(key, len(group)))
    print(group.head())
# Out:
# Cluster 0: 127 observations
#                                     uid       id.orig_h  id.orig_p        id.resp_h  id.resp_p  trans_depth method             host                                                uri referrer  ... username  password  proxied orig_fuids orig_mime_types          resp_fuids resp_mime_types          x          y cluster
# ts                                                                                                                                                                                               ...
# 2012-03-16 07:30:01  Cmdg6B2p0B0QN8cWrd  192.168.202.79      50731  192.168.229.251         80            1    GET  192.168.229.251                                                  /        -  ...        -         -        -          -               -  FB3BBm49OLiy39Weih       text/html  21.266726  -3.036837       0
# 2012-03-16 07:30:01  Cafz4F42G61JHIJwAk  192.168.202.79      50746  192.168.229.251         80            1    GET  192.168.229.251  /sdk/../../../../../../../etc/vmware/hostd/vmI...        -  ...        -         -        -          -               -  FQXKUf1ao7P4Bl12L9      text/plain  27.325996 -15.836072       0
# 2012-03-16 07:30:01  C7sXFH2zigwKylBJeb  192.168.202.79      50748  192.168.229.251         80            1    GET  192.168.229.251  /sdk/../../../../../../../etc/vmware/hostd/vmI...        -  ...        -         -        -          -               -   FWuwyFftwykPyC9if      text/plain  27.350201 -15.862030       0
# 2012-03-16 07:30:02   CnSkQClMvfFkLH7q4  192.168.202.79      50750  192.168.229.251         80            1    GET  192.168.229.251          /../../../../../../../../../../etc/passwd        -  ...        -         -        -          -               -   FseLdjUwckdmFroBg      text/plain  27.350163 -15.861917       0
# 2012-03-16 07:30:02  CRc97j3mzYSur3p8fh  192.168.202.79      50751  192.168.229.251         80            1    GET  192.168.229.251            /../../../../../../../../../../boot.ini        -  ...        -         -        -          -               -  FZSjDX2eGie7LSQjIh      text/plain  27.350138 -15.861859       0
#
# [5 rows x 29 columns]
#
# Cluster 1: 148 observations
#                                     uid       id.orig_h  id.orig_p        id.resp_h  id.resp_p  trans_depth method             host             uri referrer  ... username  password  proxied orig_fuids orig_mime_types resp_fuids resp_mime_types         x          y cluster
# ts                                                                                                                                                            ...
# 2012-03-16 07:30:00  CHEt7z3AzG4gyCNgci  192.168.202.79      50465  192.168.229.251         80            1   HEAD  192.168.229.251  /DEASLog02.nsf        -  ...        -         -        -          -               -          -               -  1.127772 -33.035049       1
# 2012-03-16 07:30:00  CKnDAp2ohlvN6rpiXl  192.168.202.79      50467  192.168.229.251         80            1   HEAD  192.168.229.251  /DEASLog03.nsf        -  ...        -         -        -          -               -          -               -  1.026558 -33.075424       1
# 2012-03-16 07:30:00  CNTrjn42F3LB58MZH6  192.168.202.79      50469  192.168.229.251         80            1   HEAD  192.168.229.251  /DEASLog04.nsf        -  ...        -         -        -          -               -          -               -  0.914358 -33.119667       1
# 2012-03-16 07:30:00  C1D7mK1PlzKEnEyG03  192.168.202.79      50471  192.168.229.251         80            1   HEAD  192.168.229.251  /DEASLog05.nsf        -  ...        -         -        -          -               -          -               -  1.068465 -32.687183       1
# 2012-03-16 07:30:00   CGF1bVMyl9ALKI32l  192.168.202.79      50473  192.168.229.251         80            1   HEAD  192.168.229.251    /DEASLog.nsf        -  ...        -         -        -          -               -          -               -  0.993970 -32.620308       1
#
# [5 rows x 29 columns]
#
# Cluster 2: 66 observations
#                                     uid       id.orig_h  id.orig_p        id.resp_h  id.resp_p  trans_depth method             host                                         uri referrer  ... username  password  proxied orig_fuids orig_mime_types          resp_fuids resp_mime_types          x         y cluster
# ts                                                                                                                                                                                        ...
# 2012-03-16 07:30:55  CWBIYZ1BUVq66Hq4u1  192.168.202.79      45505  192.168.229.101         80            1    GET  192.168.229.101                                  /names.nsf        -  ...        -         -        -          -               -  Faf9vq4KCs9wEFNksb       text/html  26.147530  8.883194       2
# 2012-03-16 07:44:32  C3BqvH2pQ3YIF0u8j7  192.168.202.79      49053  192.168.229.101         80            1    GET                -                                           /        -  ...        -         -        -          -               -  FSZqf33Rkne2MeHYhf       text/html  21.029461 -0.323912       2
# 2012-03-16 07:46:46   CLXrX2yt0TJt1WvH1  192.168.202.79      49579  192.168.229.101         80            1    GET  192.168.229.101                               /wp-login.php        -  ...        -         -        -          -               -  FlJuts1kX6Cao0B8pc       text/html  25.669952  8.566892       2
# 2012-03-16 07:46:46  Cd3xEo39DjRgYL6yue  192.168.202.79      49604  192.168.229.101         80            1    GET  192.168.229.101  /?=PHPE9568F36-D428-11d2-A769-00AA001ACF42        -  ...        -         -        -          -               -  FTzdr73LBN1R4R3F73       text/html  21.766113  4.756673       2
# 2012-03-16 07:46:46  C64v5d1Dsdvldr6pnb  192.168.202.79      49607  192.168.229.101         80            1    GET  192.168.229.101                               /jmx-console/        -  ...        -         -        -          -               -  Fk925S1CxiQKBG1Csd       text/html  25.629810  8.543162       2
#
# [5 rows x 29 columns]
#
# Cluster 3: 39 observations
#                                     uid       id.orig_h  id.orig_p        id.resp_h  id.resp_p  trans_depth method             host             uri referrer  ... username  password  proxied orig_fuids orig_mime_types          resp_fuids resp_mime_types          x         y cluster
# ts                                                                                                                                                            ...
# 2012-03-16 07:30:55  CoNOSc2XPv9SVSz259  192.168.202.79      34494  192.168.229.153       5357            1    GET  192.168.229.153      /names.nsf        -  ...        -         -        -          -               -  FxVuYu2W38New5rLv9       text/html -44.803432  8.051619       3
# 2012-03-16 07:44:37   CLaDXHlwlZ2tAVMN4  192.168.202.79      38172  192.168.229.153       5357            1    GET                -               /        -  ...        -         -        -          -               -   Fip4AB4dMsANgRSBg       text/html -43.113110  7.725374       3
# 2012-03-16 07:46:46  Ccpqm12mmqicYg9HUa  192.168.202.79      38632  192.168.229.153       5357            1    GET  192.168.229.153         /cacti/        -  ...        -         -        -          -               -   FexFRkHYVrdWMM1Va       text/html -44.472458  7.057739       3
# 2012-03-16 07:46:46  CjxTx93zmhxfXKNfHf  192.168.202.79      38641  192.168.229.153       5357            1    GET  192.168.229.153               /        -  ...        -         -        -          -               -  FPoPUb1DbwdnUvoHO4       text/html -44.703350  6.920225       3
# 2012-03-16 07:46:46   C95FHTJJ0ZyjadNL2  192.168.202.79      38642  192.168.229.153       5357            1    GET  192.168.229.153  /manager/html/        -  ...        -         -        -          -               -  F26Jxc4USxVNS5RPxa       text/html -44.590675  6.975479       3
#
# [5 rows x 29 columns]
#
# Cluster 4: 89 observations
#                                     uid       id.orig_h  id.orig_p        id.resp_h  id.resp_p  trans_depth method             host          uri referrer  ... username  password  proxied orig_fuids orig_mime_types resp_fuids resp_mime_types         x          y cluster
# ts                                                                                                                                                         ...
# 2012-03-16 07:46:46  CJY2fh3cHyxI2ExQVd  192.168.202.79      38606  192.168.229.153       5357            1   HEAD  192.168.229.153            /        -  ...        -         -        -          -               -          -               -  6.198928  44.592033       4
# 2012-03-16 07:46:47  CtcS7t3Wu1emPQqAMe  192.168.202.79      38675  192.168.229.153       5357            1   HEAD  192.168.229.153       /blog/        -  ...        -         -        -          -               -          -               -  5.874893  44.556259       4
# 2012-03-16 07:46:47  CWkbwx3f1gxS3p7PRh  192.168.202.79      38687  192.168.229.153       5357            1   HEAD  192.168.229.153     /weblog/        -  ...        -         -        -          -               -          -               -  5.797020  44.427658       4
# 2012-03-16 07:46:47  CJ3zul1Q5PZqXSocD4  192.168.202.79      38703  192.168.229.153       5357            1   HEAD  192.168.229.153    /weblogs/        -  ...        -         -        -          -               -          -               -  5.642653  44.608452       4
# 2012-03-16 07:46:48  Cku1YT2T1g3YPxvThd  192.168.202.79      38714  192.168.229.153       5357            1   HEAD  192.168.229.153  /wordpress/        -  ...        -         -        -          -               -          -               -  5.516031  44.699543       4
#
# [5 rows x 29 columns]
#
# Cluster 5: 131 observations
#                                     uid       id.orig_h  id.orig_p        id.resp_h  id.resp_p  trans_depth method             host           uri referrer  ... username  password  proxied orig_fuids orig_mime_types          resp_fuids resp_mime_types          x          y cluster
# ts                                                                                                                                                          ...
# 2012-03-16 07:30:55  Cb0KNJ1HLYmtwxQpQ6  192.168.202.79      36000  192.168.229.156         80            1    GET  192.168.229.156    /names.nsf        -  ...        -         -        -          -               -   FBWk1yxC6UWbT0Zn4       text/html -10.963186   3.839154       5
# 2012-03-16 07:42:35   CuW39ZrdntPxUf4k6  192.168.202.76      52411   192.168.28.102         80            1    GET   192.168.28.102             /        -  ...        -         -        -          -               -   FIFDLfTAIRTlvXeY2       text/html  -0.824375  11.385704       5
# 2012-03-16 07:42:35   CuW39ZrdntPxUf4k6  192.168.202.76      52411   192.168.28.102         80            2    GET   192.168.28.102  /favicon.ico        -  ...        -         -        -          -               -  F4emiE4fL9k98gA8Ih       text/html  -0.824639  11.384045       5
# 2012-03-16 07:42:35   CuW39ZrdntPxUf4k6  192.168.202.76      52411   192.168.28.102         80            3    GET   192.168.28.102  /favicon.ico        -  ...        -         -        -          -               -  Ftn3eD3oCgUbDhFUn9       text/html  -0.825090  11.382269       5
# 2012-03-16 07:42:35   CuW39ZrdntPxUf4k6  192.168.202.76      52411   192.168.28.102         80            4    GET   192.168.28.102  /favicon.ico        -  ...        -         -        -          -               -  FFMNBU2145wHG3dePj       text/html  -0.825852  11.384132       5
#
# [5 rows x 29 columns]

# %% [markdown]
# Lets Investigate the clusters of data
#
# We cramed a bunch of features into the clustering algorithm. The features were both numerical and categorical. So did the clustering 'do the right thing'? Well first some caveats and disclaimers:
# * Working with a small amount of data
#
# How the clustering did on both numeric and categorical data combined?

# %% [markdown]
# The unsupervised machine learning technique of clustering data inot similar groups can be useful and fairly efficient in most cases. The big trick as you saw earlier was how you pick the number of clusters to make (the K hyperparameter). The number of clusters may vary dramatically depending on the characteristics of the data. The different types of variables (numeric or categorical) , how the data is normalized/encoded and the distance metric used.

# %% [markdown]
# ### Silhouetter Scoring
#
# The silhouetter value is a measure of how similar an object is to its own cluster (cohesion) compared to other clusters (separation). The sillhouetter ranges from -1 to 1, where a high value indicates that the object is well matched to its own cluster and poorly matched to neighboring clusters. If most objects have a high value, then the clustering configuration is appropriate. If many points have a low or negative value, then the clusering configuration may have too many or too few clusters.

# %%
from sklearn.metrics import silhouette_score

scores = []
clusters = range(2,20)
for K in clusters:
    
    clusterer = KMeans(n_clusters=K)
    cluster_labels = clusterer.fit_predict(bro_matrix)
    score = silhouette_score(bro_matrix, cluster_labels)
    scores.append(score)

# Plot it out
pd.DataFrame({'Num Clusters':clusters, 'score':scores}).plot(x='Num Clusters', y='score')

# %% [markdown]
# Silhouette graphs shows that maybe 6 is the 'optimal' number of clusters
# 'Optimal': Human intuition and clustering involves interpretation/pattern finding and is often partially subjective
# For large datasets running an exhaustive search can be time consuming
# For large datasets you can often get a large K using max score, so pick the 'knee' of the graph as your K

# %% [markdown]
# # DBSCAN
#
# Density-based spatial clustering is a data clustering algorithm that given a set of points in space, groups points that are closely packed together and marking low-density regions as outliers.
#
# You don't have to pick K
# There are other hyperparameters (eps and min_samples) but defaults often work well

# %%
http_df['cluster_db'] = DBSCAN().fit_predict(bro_matrix)
print('Number of Clusters: {:d}'.format(http_df['cluster_db'].nunique()))
# Out:
# Number of Clusters: 15

# %% [markdown]
# So obviously we got a bit lucky here and for different datasets with different feature distributions DBSCAN may not give you the optimal number of clusters right off the bat. There are two hyperparameters that can be tweeked but like we said the defaults often work well.
#
# Clustering it a good technique to include in your toolset. Understanding the K hyperparameter and how to determine optimal K (or not if you're using DBSCAN) is a good trick to know.

# %% [markdown]
# References:
# 1. https://github.com/SuperCowPowers/bat
